# %%
from type import Abbreviation, CrfFeatures, CrfLabelSequence
import json
import pandas as pd

# %%
# 前処理した略語データを読み込む
data = list(map(Abbreviation.model_validate, json.load(open("./data/abbreviation.json", "r"))))
X = [*map(CrfFeatures.from_abbreviation, data)]
y = list(map(CrfLabelSequence.from_abbreviation, data))
# ラベルの番号振り
CrfFeatures.assign_feature_idx(X)

# %%
df = pd.DataFrame([x.model_dump() for row in X for x in row])

# %%
pd.get_dummies(df)
# Out:
#       is_syllabic_nasal  is_sokuon  is_long  next_is_syllabic_nasal  \
# 0                 False      False    False                   False
# 1                 False      False    False                   False
# 2                 False      False    False                   False
# 3                 False      False    False                   False
# 4                 False      False     True                   False
# ...                 ...        ...      ...                     ...
# 9365               True      False    False                   False
# 9366              False      False    False                    True
# 9367               True      False    False                   False
# 9368              False      False    False                   False
# 9369              False      False    False                   False
#
#       next_is_sokuon  next_is_long  prev_is_syllabic_nasal  prev_is_sokuon  \
# 0              False         False                   False           False
# 1              False         False                   False           False
# 2              False         False                   False           False
# 3              False          True                   False           False
# 4              False         False                   False           False
# ...              ...           ...                     ...             ...
# 9365           False         False                   False           False
# 9366           False         False                   False           False
# 9367           False         False                   False           False
# 9368           False         False                    True           False
# 9369           False         False                   False           False
#
#       prev_is_long  elem_num  ...  next3_mora_vu  next3_mora_wa  \
# 0            False         0  ...          False          False
# 1            False         0  ...          False          False
# 2            False         0  ...          False          False
# 3            False         0  ...          False          False
# 4            False         0  ...          False          False
# ...            ...       ...  ...            ...            ...
# 9365         False         0  ...          False          False
# 9366         False         1  ...          False          False
# 9367         False         1  ...          False          False
# 9368         False         1  ...          False          False
# 9369         False         1  ...          False          False
#
#       next3_mora_we  next3_mora_ya  next3_mora_yo  next3_mora_yu  \
# 0             False          False          False          False
# 1             False          False          False          False
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False          False
# ...             ...            ...            ...            ...
# 9365          False          False          False          False
# 9366          False          False          False          False
# 9367          False          False          False          False
# 9368          False          False          False          False
# 9369          False          False          False          False
#
#       next3_mora_za  next3_mora_ze  next3_mora_zo  next3_mora_zu
# 0             False          False          False          False
# 1             False          False          False          False
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False          False
# ...             ...            ...            ...            ...
# 9365          False          False          False          False
# 9366          False          False          False          False
# 9367          False          False          False          False
# 9368          False          False          False          False
# 9369          False          False          False          False
#
# [9370 rows x 972 columns]

# %%
ctg = pd.Categorical(df["prev1_consonant"]).to_list()
# Out:
# /var/folders/4x/vf52k2q52wx0sqrm0t5hfr040000gn/T/ipykernel_47065/3654737488.py:1: FutureWarning: Categorical.to_list is deprecated and will be removed in a future version. Use obj.tolist() instead
#   ctg = pd.Categorical(df["prev1_consonant"]).to_list()
